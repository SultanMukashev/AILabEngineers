# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/User/AILabEngineers/task3/data/raw/krisha1.csv')
df.head()
# Out:
#         price                                               text   area  \
# 0         NaN                 Не удается получить доступ к сайту    NaN
# 1         NaN                                Страница не найдена    NaN
# 2         NaN                                Страница не найдена    NaN
# 3  17900000.0  1-комнатная квартира · 45 м² · 3/9 этаж, Кайым...  45 м²
# 4  17600000.0  1-комнатная квартира · 39 м² · 5/7 этаж, Болек...  39 м²
#
#   flat_toilets          balcony  current_floors  total_floors  ceiling dorm  \
# 0          NaN              NaN             NaN           NaN      NaN  NaN
# 1          NaN              NaN             NaN           NaN      NaN  NaN
# 2          NaN              NaN             NaN           NaN      NaN  NaN
# 3   раздельный  балкон и лоджия             3.0           9.0      NaN  NaN
# 4  совмещенный           лоджия             5.0           7.0      2.8  NaN
#
#   mortgage    year type_of_house condition repair_status type_of_floor  \
# 0      NaN     NaN           NaN       NaN           NaN           NaN
# 1      NaN     NaN           NaN       NaN           NaN           NaN
# 2      NaN     NaN           NaN       NaN           NaN           NaN
# 3      NaN  2020.0           NaN       NaN     полностью       ламинат
# 4      NaN  2019.0     кирпичный       NaN     полностью       ламинат
#
#                                 location
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3    Астана, Нура р-н\nпоказать на карте
# 4  Астана, Алматы р-н\nпоказать на карте

# %%
for i in df['text']:
    if i in ['Не удается получить доступ к сайту', 'Страница не найдена']:
        df.drop(df[df['text'] == i].index, inplace=True)
    
df = df.reset_index(drop=True)

# %%
df
# Out:
#             price                                               text  \
# 0      17900000.0  1-комнатная квартира · 45 м² · 3/9 этаж, Кайым...
# 1      17600000.0  1-комнатная квартира · 39 м² · 5/7 этаж, Болек...
# 2      29900000.0  2-комнатная квартира · 48.76 м² · 2/9 этаж, Жо...
# 3      27000000.0  3-комнатная квартира · 85 м² · 8/12 этаж, Майл...
# 4     105000000.0  4-комнатная квартира · 128.5 м² · 3/6 этаж, Ще...
# ...           ...                                                ...
# 6632   13500000.0  1-комнатная квартира · 32.9 м² · 4/4 этаж, мкр...
# 6633   29000000.0  2-комнатная квартира · 50 м² · 8/12 этаж, мкр ...
# 6634   30000000.0  3-комнатная квартира · 70 м² · 2/5 этаж, мкр Н...
# 6635   24500000.0  1-комнатная квартира · 34.9 м² · 4/5 этаж, Мик...
# 6636   18000000.0  3-комнатная квартира · 50 м² · 2/5 этаж, Новат...
#
#           area flat_toilets          balcony  current_floors  total_floors  \
# 0        45 м²   раздельный  балкон и лоджия             3.0           9.0
# 1        39 м²  совмещенный           лоджия             5.0           7.0
# 2     48.76 м²          NaN              NaN             2.0           9.0
# 3        85 м²   раздельный              NaN             8.0          12.0
# 4     128.5 м²          NaN              NaN             3.0           6.0
# ...        ...          ...              ...             ...           ...
# 6632   32.9 м²  совмещенный              NaN             4.0           4.0
# 6633     50 м²          NaN              NaN             8.0          12.0
# 6634     70 м²          NaN              NaN             2.0           5.0
# 6635   34.9 м²          NaN              NaN             4.0           5.0
# 6636     50 м²  совмещенный              NaN             2.0           5.0
#
#       ceiling dorm mortgage    year type_of_house         condition  \
# 0         NaN  NaN      NaN  2020.0           NaN               NaN
# 1         2.8  NaN      NaN  2019.0     кирпичный               NaN
# 2         3.0  нет      NaN  2025.0    монолитный  черновая отделка
# 3         3.0  нет      NaN  2024.0    монолитный               NaN
# 4         3.0  нет      NaN  2025.0    монолитный               NaN
# ...       ...  ...      ...     ...           ...               ...
# 6632      NaN  нет      NaN  2010.0           NaN     свежий ремонт
# 6633      NaN  NaN      NaN  2024.0           NaN               NaN
# 6634      NaN  NaN      NaN  1972.0           NaN               NaN
# 6635      2.8  нет      NaN  2023.0    монолитный     свежий ремонт
# 6636      2.5  нет      NaN  1973.0     панельный     свежий ремонт
#
#      repair_status type_of_floor  \
# 0        полностью       ламинат
# 1        полностью       ламинат
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
# ...            ...           ...
# 6632           NaN      линолеум
# 6633           NaN           NaN
# 6634           NaN           NaN
# 6635     полностью       ламинат
# 6636      частично       ламинат
#
#                                              location
# 0                 Астана, Нура р-н\nпоказать на карте
# 1               Астана, Алматы р-н\nпоказать на карте
# 2                           Астана\nпоказать на карте
# 3               Астана, Алматы р-н\nпоказать на карте
# 4           Алматы, Ауэзовский р-н\nпоказать на карте
# ...                                               ...
# 6632            Атырау, мкр Нурсая\nпоказать на карте
# 6633         Шымкент, Абайский р-н\nпоказать на карте
# 6634     Караганда, Казыбек би р-н\nпоказать на карте
# 6635        Алматы, Алатауский р-н\nпоказать на карте
# 6636  Усть-Каменогорск, Ульбинский\nпоказать на карте
#
# [6637 rows x 16 columns]
