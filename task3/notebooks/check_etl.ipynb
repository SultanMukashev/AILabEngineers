# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/User/AILabEngineers/task3/data/processed/krisha_cleaned.csv')
df
# Out:
#             price                                               text    area  \
# 0      17900000.0  1-комнатная квартира · 45 м² · 3/9 этаж, Кайым...   45.00
# 1      17600000.0  1-комнатная квартира · 39 м² · 5/7 этаж, Болек...   39.00
# 2      29900000.0  2-комнатная квартира · 48.76 м² · 2/9 этаж, Жо...   48.76
# 3      27000000.0  3-комнатная квартира · 85 м² · 8/12 этаж, Майл...   85.00
# 4     105000000.0  4-комнатная квартира · 128.5 м² · 3/6 этаж, Ще...  128.50
# ...           ...                                                ...     ...
# 6632   13500000.0  1-комнатная квартира · 32.9 м² · 4/4 этаж, мкр...   32.90
# 6633   29000000.0  2-комнатная квартира · 50 м² · 8/12 этаж, мкр ...   50.00
# 6634   30000000.0  3-комнатная квартира · 70 м² · 2/5 этаж, мкр Н...   70.00
# 6635   24500000.0  1-комнатная квартира · 34.9 м² · 4/5 этаж, Мик...   34.90
# 6636   18000000.0  3-комнатная квартира · 50 м² · 2/5 этаж, Новат...   50.00
#
# ...

# %%
# Out:
# array(['Нура р-н', 'Алматы р-н', nan, 'Ауэзовский р-н', 'Есильский р-н',
#        'Наурызбайский р-н', 'Сарыарка р-н', 'Алатауский р-н',
#        'Сарайшык р-н', 'Турксибский р-н', 'Алмалинский р-н',
#        'Алматинская обл.', 'Восточно-Казахстанская обл.',
#        'Акмолинская обл.', 'Мангистауская обл.', 'Бостандыкский р-н',
#        'Каратауский р-н', '13-й мкр', '31Б мкр', 'Жамбылская обл.',
#        'Жетысуский р-н', 'Медеуский р-н', 'Павлодарская обл.',
#        'р-н Байконур', 'Казыбек би р-н', 'Западно-Казахстанская обл.',
#        'мкр Сары Арка', 'мкр. Алтын орда', '28-й мкр', 'Улытау обл.',
#        '17-й мкр', 'мкр Жана Орда', 'жилой массив Жилянка',
#        'Карагандинская обл.', 'Костанайская обл.', 'Абайский р-н',
#        'Жетысу обл.', 'Аль-Фарабийский р-н', 'Туркестанская обл.',
#        'мкр Кадыра Мырза-Али', 'мкр Жилгородок', '11-й мкр', '20а мкр',
#        'Абай обл.', '15-й мкр', '29а мкр', 'Енбекшинский р-н',
# ...
