# %%
import pandas as pd

# %%
df = pd.read_csv("krisha_all_data.csv")

# %%
df
# Out:
#            price                                               text     area  \
# 0            NaN                 Не удается получить доступ к сайту      NaN
# 1            NaN                                Страница не найдена      NaN
# 2            NaN                                Страница не найдена      NaN
# 3     17900000.0  1-комнатная квартира · 45 м² · 3/9 этаж, Кайым...    45 м²
# 4     17600000.0  1-комнатная квартира · 39 м² · 5/7 этаж, Болек...    39 м²
# ...          ...                                                ...      ...
# 6640  13500000.0  1-комнатная квартира · 32.9 м² · 4/4 этаж, мкр...  32.9 м²
# 6641  29000000.0  2-комнатная квартира · 50 м² · 8/12 этаж, мкр ...    50 м²
# 6642  30000000.0  3-комнатная квартира · 70 м² · 2/5 этаж, мкр Н...    70 м²
# 6643  24500000.0  1-комнатная квартира · 34.9 м² · 4/5 этаж, Мик...  34.9 м²
# 6644  18000000.0  3-комнатная квартира · 50 м² · 2/5 этаж, Новат...    50 м²
#
# ...

# %%
df.isnull().sum()
# Out:
# price             1304
# text                 5
# area                13
# flat_toilets      2389
# balcony           5710
# current_floors    1440
# total_floors      1440
# ceiling           2355
# dorm              1982
# mortgage          6330
# year                13
# type_of_house      408
# condition         3752
# repair_status     3017
# type_of_floor     3243
# location            13
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6645 entries, 0 to 6644
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           5341 non-null   float64
#  1   text            6640 non-null   object
#  2   area            6632 non-null   object
#  3   flat_toilets    4256 non-null   object
#  4   balcony         935 non-null    object
#  5   current_floors  5205 non-null   float64
#  6   total_floors    5205 non-null   float64
#  7   ceiling         4290 non-null   float64
#  8   dorm            4663 non-null   object
#  9   mortgage        315 non-null    object
#  10  year            6632 non-null   float64
#  11  type_of_house   6237 non-null   object
#  12  condition       2893 non-null   object
#  13  repair_status   3628 non-null   object
#  14  type_of_floor   3402 non-null   object
#  15  location        6632 non-null   object
# dtypes: float64(5), object(11)
# ...

# %%
df.count()
# Out:
# price             5341
# text              6640
# area              6632
# flat_toilets      4256
# balcony            935
# current_floors    5205
# total_floors      5205
# ceiling           4290
# dorm              4663
# mortgage           315
# year              6632
# type_of_house     6237
# condition         2893
# repair_status     3628
# type_of_floor     3402
# location          6632
# dtype: int64

# %%
df['area']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3         45 м²
# 4         39 м²
#          ...
# 6640    32.9 м²
# 6641      50 м²
# 6642      70 м²
# 6643    34.9 м²
# 6644      50 м²
# Name: area, Length: 6645, dtype: object

# %%
df['price'].describe().apply(lambda x: f"{x:,.0f}")
# Out:
# count            5,341
# mean        39,411,923
# std         39,450,610
# min          3,000,000
# 25%         20,200,000
# 50%         29,800,000
# 75%         45,000,000
# max      1,196,000,000
# Name: price, dtype: object

# %%
df["text"][4]
# Out:
# '1-комнатная квартира · 39 м² · 5/7 этаж, Болекпаева 8'
